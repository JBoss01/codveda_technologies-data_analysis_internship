# %%
# Level 3 — Task 2: Building Dashboards with Power BI
# This task was completed entirely in Microsoft Power BI Desktop.
# The dashboard file is located at: dashboards/housing_market_analytics.pbix
#
# Tools used: Power BI Desktop, DAX, Power Query
# Dataset: Boston Housing Dataset (data/processed/house_cleaned.csv)
#
# Key steps completed:
# 1. Imported and cleaned the dataset in Power Query
# 2. Built calculated measures using DAX
# 3. Created 5 interactive visualisations
# 4. Added 3 slicers for cross filtering
# 5. Applied consistent colour theme and styling
# 6. Published to Power BI service

print("Dashboard built in Power BI Desktop.")
print("See dashboards/housing_market_analytics.pbix for the full file.")
print("See reports/ for the written summary of findings.")
# Out:
# Dashboard built in Power BI Desktop.
# See dashboards/housing_market_analytics.pbix for the full file.
# See reports/ for the written summary of findings.
